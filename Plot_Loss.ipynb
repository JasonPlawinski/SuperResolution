# %%
import numpy as np
import math, random
import matplotlib.pyplot as plt

# %%
LossD = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/TextureMSEx4GAN/Loss/D_GAN.txt")
LossG = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/TextureMSEx4GAN/Loss/G_GAN.txt")
LossTot = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/TextureMSEx4GAN/Loss/Loss_GAN.txt")
LossMSE = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/TextureMSEx4GAN/Loss/MSE_GAN.txt")

# %%
plt.plot(LossD[:])
plt.show()
plt.plot(LossG[:])
plt.show()
plt.plot(LossMSE[:])
plt.show()
plt.plot(LossTot[:])
plt.show()

# %%
LossD = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/TextureCombx4GAN/Loss/D_GAN.txt")
LossG = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/TextureCombx4GAN/Loss/G_GAN.txt")
LossTot = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/TextureCombx4GAN/Loss/Loss_GAN.txt")
LossMSE = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/TextureCombx4GAN/Loss/MSE_GAN.txt")

# %%
plt.plot(LossD[:])
plt.show()
plt.plot(LossG[:])
plt.show()
plt.plot(LossMSE[:])
plt.show()
plt.plot(LossTot[:])
plt.show()

# %%
LossD = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/GANtest/D_GANbal.txt")
LossG = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/GANtest/G_GANbal.txt")
Dsmooth = LossD[:22000].reshape([200,110])
Gsmooth = LossG[:22000].reshape([200,110])
MD = np.mean(Dsmooth, axis = 0)
MG = np.mean(Gsmooth, axis = 0)
plt.plot(LossD[:])
plt.show()
plt.plot(LossG[:])
plt.show()
plt.plot(MD[:])
plt.show()
plt.plot(MG[:])
plt.show()

# %%
LossD = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/GANtest/D_GAN.txt")
LossG = np.loadtxt("/home/jasonplawinski/Documents/UpscalingTexture/Results/GANtest/G_GAN.txt")
plt.plot(LossD[:])
plt.show()
plt.plot(LossG[:])
plt.show()
Dsmooth = LossD[:220000].reshape([20000,110])
Gsmooth = LossG[:220000].reshape([20000,110])
MD = np.mean(Dsmooth, axis = 0)
MG = np.mean(Gsmooth, axis = 0)
plt.plot(LossD[:])
plt.show()
plt.plot(LossG[:])
plt.show()
plt.plot(MD[:])
plt.show()
plt.plot(MG[:])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9bb93a37bb0d> in <module>()
#       5 plt.plot(LossG[:])
#       6 plt.show()
# ----> 7 Dsmooth = LossD[:220000].reshape([20000,110])
#       8 Gsmooth = LossG[:220000].reshape([20000,110])
#       9 MD = np.mean(Dsmooth, axis = 0)
#
# ValueError: cannot reshape array of size 220000 into shape (20000,110)
